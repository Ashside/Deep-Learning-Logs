# %%
import torch
from torch import nn
from torch.nn import functional as F
import traintools
# Out:
# 2025-08-19 22:27:17,964 - INFO - NumExpr defaulting to 16 threads.

# %% [markdown]
# ![image.png](attachment:ef7a41ad-fa6a-4c4d-a29e-defc804063e6.png)

# %%
class Residual(nn.Module):
    def __init__(self,input_channels,num_channels,use_1x1conv=False,strides=1):
        super(Residual,self).__init__()
        self.conv1 = nn.Conv2d(input_channels,num_channels,kernel_size=3,padding=1,stride=strides)
        self.conv2 = nn.Conv2d(num_channels,num_channels,kernel_size=3,padding=1)
        if use_1x1conv:
            self.conv3 = nn.Conv2d(input_channels,num_channels,kernel_size=1,stride=strides)
        else:
            self.conv3 = None
        self.bn1 = nn.BatchNorm2d(num_channels)
        self.bn2 = nn.BatchNorm2d(num_channels)

    def forward(self,X):
        Y = F.relu(self.bn1(self.conv1(X)))
        Y = self.bn2(self.conv2(Y))
        if self.conv3:
            X = self.conv3(X)
        Y += X
        return F.relu(Y)

# %%
blk = Residual(3,3)
X = torch.rand(4,3,6,6)
Y = blk(X)
print(Y.shape)
# Out:
# torch.Size([4, 3, 6, 6])

# %%
blk = Residual(3,6,use_1x1conv=True,strides=2)
Y = blk(X)
print(Y.shape)
# Out:
# torch.Size([4, 6, 3, 3])

# %%
b1 = nn.Sequential(
    nn.Conv2d(1,64,kernel_size=7,stride=2,padding=3),
    nn.BatchNorm2d(64),
    nn.ReLU(),
    nn.MaxPool2d(kernel_size=3,stride=2,padding=1)
)
def resnet_block(input_channels,num_channels,num_residuals,strides=1,first_block=False):
    blk = []
    for i in range(num_residuals):
        if i == 0 and not first_block:
            blk.append(Residual(input_channels,num_channels,use_1x1conv=True,strides=strides))
        else:
            blk.append(Residual(num_channels,num_channels))
    return nn.Sequential(*blk)
b2 = nn.Sequential(*resnet_block(64,64,num_residuals=2,first_block=True))
b3 = nn.Sequential(*resnet_block(64,128,num_residuals=2))
b4 = nn.Sequential(*resnet_block(128,256,num_residuals=2))
b5 = nn.Sequential(*resnet_block(256,512,num_residuals=2))

net = nn.Sequential(
    b1,
    b2,
    b3,
    b4,
    b5,
    nn.AdaptiveAvgPool2d((1,1)), # 全局平均池化
    nn.Flatten(),
    nn.Linear(512,10)
)

# %%
X = torch.rand(1,1,224,224)
for layer in net:
    X = layer(X)
    print(layer.__class__.__name__, 'output shape:\t', X.shape)
# Out:
# Sequential output shape:	 torch.Size([1, 64, 56, 56])
# Sequential output shape:	 torch.Size([1, 64, 56, 56])
# Sequential output shape:	 torch.Size([1, 128, 56, 56])
# Sequential output shape:	 torch.Size([1, 256, 56, 56])
# Sequential output shape:	 torch.Size([1, 512, 56, 56])
# AdaptiveAvgPool2d output shape:	 torch.Size([1, 512, 1, 1])
# Flatten output shape:	 torch.Size([1, 512])
# Linear output shape:	 torch.Size([1, 10])

# %%
lr, num_epochs, batch_size = 0.05, 10, 256
train_iter, test_iter = traintools.load_data_fashion_mnist(batch_size, resize=96)
traintools.train_ch6(net, train_iter, test_iter, num_epochs, lr, traintools.try_gpu())
# Out:
# training on cuda:0
# epoch 1, loss 0.670, train acc 0.761, test acc 0.645
# epoch 2, loss 0.337, train acc 0.876, test acc 0.675
# KeyboardInterrupt
